# %% [markdown]
# # Run NCRFpp
#
# ## 1. Training
# ## 2. Decoding

# %% [markdown]
# ### 1. Training
# #### 使用不同的config文件训练不同参数的模型

# %%
# !cat NCRFpp/train.config
# Out:
# ### use # to comment out the configure item
#
# ### I/O ###
# train_dir=./NCRFpp/data/conll_2003_simple/train.bmes
# dev_dir=./NCRFpp/data/conll_2003_simple/dev.bmes
# test_dir=./NCRFpp/data/conll_2003_simple/test.bmes
# model_dir=./NCRFpp/saved_models/bilstm-crf
# word_emb_dir=./NCRFpp/data/glove.6B.100d.txt
#
# #raw_dir=
# #decode_dir=
# #dset_dir=
# #load_model_dir=
# #char_emb_dir=
#
# norm_word_emb=False
# norm_char_emb=False
# number_normalized=True
# seg=True
# word_emb_dim=100
# char_emb_dim=30
#
# ###NetworkConfiguration###
# use_crf=True
# use_char=False
# word_seq_feature=LSTM
# char_seq_feature=CNN
# #feature=[POS] emb_size=20
# #feature=[Cap] emb_size=20
# #nbest=1
#
# ###TrainingSetting###
# status=train
# optimizer=ADAM
# iteration=10
# batch_size=32
# ave_batch_loss=True
#
# ###Hyperparameters###
# cnn_layer=4
# char_hidden_dim=50
# hidden_dim=200
# dropout=0.5
# lstm_layer=1
# bilstm=True
# learning_rate=0.0003
# lr_decay=0.05
# momentum=0
# l2=1e-8
# gpu=True
# #clip=

# %%
# 更改模型训练参数，训练模型
# !python ./NCRFpp/main.py --config NCRFpp/train.config
# Out:
# Seed num: 42
# MODEL: train
# Load pretrained word embedding, norm: False, dir: ./NCRFpp/data/glove.6B.100d.txt
# Embedding:
#      pretrain word:400000, prefect match:11415, case_match:11656, oov:2234, oov%:0.08827945941673912
# Training model...
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# DATA SUMMARY START:
#  I/O:
#      Start   Sequence   Laebling   task...
#      Tag          scheme: BIO
#      Split         token:  |||
#      MAX SENTENCE LENGTH: 250
#      MAX   WORD   LENGTH: -1
#      Number   normalized: True
#      Word  alphabet size: 25306
#      Char  alphabet size: 78
#      Label alphabet size: 10
#      Word embedding  dir: ./NCRFpp/data/glove.6B.100d.txt
#      Char embedding  dir: None
#      Word embedding size: 100
#      Char embedding size: 30
#      Norm   word     emb: False
#      Norm   char     emb: False
#      Train  file directory: ./NCRFpp/data/conll_2003_simple/train.bmes
#      Dev    file directory: ./NCRFpp/data/conll_2003_simple/dev.bmes
#      Test   file directory: ./NCRFpp/data/conll_2003_simple/test.bmes
#      Raw    file directory: None
#      Dset   file directory: None
#      Model  file directory: ./NCRFpp/saved_models/bilstm-crf
#      Loadmodel   directory: None
#      Decode file directory: None
#      Train instance number: 14986
#      Dev   instance number: 3465
#      Test  instance number: 3683
#      Raw   instance number: 0
#      FEATURE num: 0
#  ++++++++++++++++++++++++++++++++++++++++
#  Model Network:
#      Model        use_crf: True
#      Model word extractor: LSTM
#      Model       use_char: False
#  ++++++++++++++++++++++++++++++++++++++++
#  Training:
#      Optimizer: ADAM
#      Iteration: 10
#      BatchSize: 32
#      Average  batch   loss: True
#  ++++++++++++++++++++++++++++++++++++++++
#  Hyperparameters:
#      Hyper              lr: 0.0003
#      Hyper        lr_decay: 0.05
#      Hyper         HP_clip: None
#      Hyper        momentum: 0.0
#      Hyper              l2: 1e-08
#      Hyper      hidden_dim: 200
#      Hyper         dropout: 0.5
#      Hyper      lstm_layer: 1
#      Hyper          bilstm: True
#      Hyper             GPU: True
# DATA SUMMARY END.
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# build sequence labeling network...
# use_char:  False
# word feature extractor:  LSTM
# use crf:  True
# build word sequence feature extractor: LSTM...
# build word representation...
# build CRF...
# Epoch: 0/10
# Shuffle: first input word list: [1567, 4044, 10146, 237, 2656, 12133, 10]
#      Instance: 4000; Time: 13.82s; loss: 1804.1207; acc: 44184/55640=0.7941
#      Instance: 8000; Time: 11.81s; loss: 1119.8414; acc: 89966/110597=0.8135
#      Instance: 12000; Time: 11.14s; loss: 862.6239; acc: 136186/164439=0.8282
#      Instance: 14986; Time: 7.36s; loss: 563.4408; acc: 171331/204566=0.8375
# Epoch: 0 training finished. Time: 44.13s, speed: 339.58st/s,  total loss: 4350.026839733124
# totalloss: 4350.026839733124
# Right token =  46351  All token =  51577  acc =  0.8986757663299533
# Dev: time: 3.67s, speed: 955.93st/s; acc: 0.8987, p: 0.6977, r: 0.3780, f: 0.4903
# Exceed previous best f score: -10
# Save current best model in file: ./NCRFpp/saved_models/bilstm-crf.0.model
# Right token =  41791  All token =  46665  acc =  0.8955534126218794
# Test: time: 3.53s, speed: 1061.99st/s; acc: 0.8956, p: 0.6218, r: 0.3915, f: 0.4804
# Epoch: 1/10
# Shuffle: first input word list: [2193, 14]
#      Instance: 4000; Time: 10.45s; loss: 660.5208; acc: 48439/54376=0.8908
#      Instance: 8000; Time: 11.45s; loss: 599.5141; acc: 99053/110434=0.8969
#      Instance: 12000; Time: 11.60s; loss: 528.7650; acc: 148169/164574=0.9003
#      Instance: 14986; Time: 8.31s; loss: 375.9128; acc: 184643/204566=0.9026
# Epoch: 1 training finished. Time: 41.82s, speed: 358.39st/s,  total loss: 2164.7126893997192
# totalloss: 2164.7126893997192
# Right token =  48262  All token =  51577  acc =  0.9357271652092988
# Dev: time: 3.76s, speed: 934.87st/s; acc: 0.9357, p: 0.7526, r: 0.6227, f: 0.6815
# Exceed previous best f score: 0.49033948258923693
# Save current best model in file: ./NCRFpp/saved_models/bilstm-crf.1.model
# Right token =  43452  All token =  46665  acc =  0.9311475409836065
# Test: time: 3.56s, speed: 1052.86st/s; acc: 0.9311, p: 0.6908, r: 0.6053, f: 0.6453
# Epoch: 2/10
# Shuffle: first input word list: [271, 8101, 231, 94, 5649, 39, 19851, 15715, 1017, 11922, 230, 12021, 157, 279, 41, 374, 6, 4510, 398, 371, 438, 555, 4512, 5805, 80, 11973, 618, 1536, 4492, 72, 158, 436, 157, 41, 5340, 18, 19, 20, 10]
#      Instance: 4000; Time: 11.38s; loss: 456.6340; acc: 49885/54329=0.9182
#      Instance: 8000; Time: 11.12s; loss: 429.1611; acc: 100038/108671=0.9206
#      Instance: 12000; Time: 9.76s; loss: 403.0860; acc: 151003/163498=0.9236
#      Instance: 14986; Time: 7.18s; loss: 295.1753; acc: 189247/204566=0.9251
# Epoch: 2 training finished. Time: 39.43s, speed: 380.05st/s,  total loss: 1584.0564498901367
# totalloss: 1584.0564498901367
# Right token =  49011  All token =  51577  acc =  0.9502491420594451
# Dev: time: 3.65s, speed: 961.34st/s; acc: 0.9502, p: 0.8290, r: 0.7154, f: 0.7680
# Exceed previous best f score: 0.6815251427518879
# Save current best model in file: ./NCRFpp/saved_models/bilstm-crf
# Exceed previous best f score: 0.8786318820347264
# Save current best model in file: ./NCRFpp/saved_models/bilstm-crf.9.model
# Right token =  45101  All token =  46665  acc =  0.9664845173041894
# Test: time: 3.54s, speed: 1057.22st/s; acc: 0.9665, p: 0.8750, r: 0.8146, f: 0.8438

# %% [markdown]
# ## 2. Decoding

# %%
# !cat NCRFpp/decode.config
# Out:
# ### Decode ###
# status=decode
# raw_dir=./NCRFpp/data/conll_2003_simple/test.bmes
# nbest=1
# decode_dir=./NCRFpp/data/conll_2003_simple/test.out
# dset_dir=./NCRFpp/saved_models/bilstm-crf.dset
# load_model_dir=./NCRFpp/saved_models/bilstm-crf.9.model

# %%
# 更改模型预测参数
# !python ./NCRFpp/main.py --config NCRFpp/decode.config
# Out:
# Seed num: 42
# MODEL: decode
# ./NCRFpp/data/conll_2003_simple/test.bmes
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# DATA SUMMARY START:
#  I/O:
#      Start   Sequence   Laebling   task...
#      Tag          scheme: BIO
#      Split         token:  |||
#      MAX SENTENCE LENGTH: 250
#      MAX   WORD   LENGTH: -1
#      Number   normalized: True
#      Word  alphabet size: 25306
#      Char  alphabet size: 78
#      Label alphabet size: 10
#      Word embedding  dir: ./NCRFpp/data/glove.6B.100d.txt
#      Char embedding  dir: None
#      Word embedding size: 100
#      Char embedding size: 30
#      Norm   word     emb: False
#      Norm   char     emb: False
#      Train  file directory: ./NCRFpp/data/conll_2003_simple/train.bmes
#      Dev    file directory: ./NCRFpp/data/conll_2003_simple/dev.bmes
#      Test   file directory: ./NCRFpp/data/conll_2003_simple/test.bmes
#      Raw    file directory: ./NCRFpp/data/conll_2003_simple/test.bmes
#      Dset   file directory: ./NCRFpp/saved_models/bilstm-crf.dset
#      Model  file directory: ./NCRFpp/saved_models/bilstm-crf
#      Loadmodel   directory: ./NCRFpp/saved_models/bilstm-crf.9.model
#      Decode file directory: ./NCRFpp/data/conll_2003_simple/test.out
#      Train instance number: 14986
#      Dev   instance number: 3465
#      Test  instance number: 3683
#      Raw   instance number: 0
#      FEATURE num: 0
#  ++++++++++++++++++++++++++++++++++++++++
#  Model Network:
#      Model        use_crf: True
#      Model word extractor: LSTM
#      Model       use_char: False
#  ++++++++++++++++++++++++++++++++++++++++
#  Training:
#      Optimizer: ADAM
#      Iteration: 10
#      BatchSize: 32
#      Average  batch   loss: True
#  ++++++++++++++++++++++++++++++++++++++++
#  Hyperparameters:
#      Hyper              lr: 0.0003
#      Hyper        lr_decay: 0.05
#      Hyper         HP_clip: None
#      Hyper        momentum: 0.0
#      Hyper              l2: 1e-08
#      Hyper      hidden_dim: 200
#      Hyper         dropout: 0.5
#      Hyper      lstm_layer: 1
#      Hyper          bilstm: True
#      Hyper             GPU: True
# DATA SUMMARY END.
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# nbest: 1
# Load Model from file:  ./NCRFpp/saved_models/bilstm-crf
# build sequence labeling network...
# use_char:  False
# word feature extractor:  LSTM
# use crf:  True
# build word sequence feature extractor: LSTM...
# build word representation...
# build CRF...
# Decode raw data, nbest: 1 ...
# Right token =  45101  All token =  46665  acc =  0.9664845173041894
# raw: time:4.14s, speed:900.39st/s; acc: 0.9665, p: 0.8750, r: 0.8146, f: 0.8438
# Predict raw 1-best result has been written into file. ./NCRFpp/data/conll_2003_simple/test.out
